# %%
import pandas as pd

# %%
# 電商數據
# 供應商
# used
root_path = "/Users/kneskung/Dataset/電商數據/"
supplier = pd.read_csv(root_path+"1_供應商/supplier.csv")
supplier.head(15)
# ignore 供應商登記地址
# Out:
#     供應商代號         供應商名稱  出貨地郵遞區號              供應商出貨地址  登記地郵遞區號  \
# 0     478    精技電腦股份有限公司      114    台北市內湖區新湖二路236號3樓     114.0
# 1     479  達麗建設事業股份有限公司      111     台北市士林區大南路361號5樓     111.0
# 2     480     鼎泰聖企業有限公司      234   新北市永和區永元路17巷7弄2號1F    234.0
# 3     482    展碁國際股份有限公司      100  台北市中正區忠孝西路一段39號2-4F    100.0
# 4     483    群光電子股份有限公司      248      新北市五股區五權路2-1號4樓    248.0
# 5     484      正裕銀樓有限公司      105   台北市松山區北市新中街13-2號1樓    105.0
# 6     488      芳展事業有限公司      807         高雄市三民區博仁街18號    807.0
# 7     490    聯強國際股份有限公司      104   台北市中山區民生東路三段75號4樓     104.0
# 8     492   士林電機廠股份有限公司      104     台北市中山區長安東路一段9號3樓      NaN
# 9     493     威華格國際有限公司      104     台北市中山區長春路40號8樓之3    104.0
# 10    496    新格實業股份有限公司      236   新北市土城區中央路三段89巷1號      236.0
# 11    498    葳肯文化事業有限公司      104    台北市中山區復興北路二號5樓之2     104.0
# 12    502      建欣電器有限公司      407     台中市西屯區大墩路949-3號       NaN
# 13    505     新各界企業有限公司      114      台北市內湖區行愛路172號1樓    114.0
# ...

# %%
# used
sku = pd.read_csv(root_path+"2_商品檔/(商品主檔)sku_20120413.csv")
sku.head(15)
# Out:
# /var/folders/1t/798ky1kx003ft5w1l83k6v9h0000gn/T/ipykernel_85839/2078227297.py:1: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   sku = pd.read_csv(root_path+"2_商品檔/(商品主檔)sku_20120413.csv")
#     供應商代號    大分類   小分類     商品編號                                 商品名稱 材積(長)  \
# 0    1000  15561  1076    51425                            居家必備修容9件組   0.0
# 1    1000  39088  2399   835450         【Inner Comfort】420丹竹炭雙加強高腰塑褲   0.0
# 2   10001  56186  3791  4621100       【Orange Bear】無修邊領緣口袋素色棉T-灰(50)    29
# 3   10001  56186  3791  4621104       【Orange Bear】無修邊領緣口袋素色棉T-灰(46)  30.0
# 4   10001  56186  3791  4621123       【Orange Bear】無修邊領緣口袋素色棉T-灰(42)  30.0
# 5   10001  56186  3791  4621128      【Orange Bear】無修邊領緣口袋素色棉T-酒紅(50)  30.0
# 6   10001  56186  3791  4621131      【Orange Bear】無修邊領緣口袋素色棉T-酒紅(46)  30.0
# 7   10001  56186  3791  4621133      【Orange Bear】無修邊領緣口袋素色棉T-酒紅(42)  30.0
# ...

# %%
# skip
product_list = pd.read_csv(root_path+"2_商品檔/2012_product_list.csv")
product_list.head()
# Out:
#       商品編號                                  商品編號.1  供應商編號  商品材積(長)cm  \
# 0  7220050  溫寶貝Hello Kitty兩用式暖暖蛋超值2入組(PI-15+PI-16)   1303        7.0
# 1  7220051        OPEN將/條碼貓兩用式暖蛋組(2入)DPO-02+DPO-05   1303        7.0
# 2  7220052                歌林充電式雙面溫熱暖暖棒(2入組)FH-R016   1303        8.0
# 3  7220053                    歌林充電式雙面溫熱暖暖棒-FH-R016   1303       19.0
# 4  7220054                溫寶貝Kitty充電式暖暖蛋(2入組)PI-15   1303        7.0
#
#    商品材積(寬)cm  商品材積(高)cm  商品材積(重量)g  倉別                   商品建檔時間
# 0       14.0       19.0        199  新豐  2012-01-01 13:33:46.760
# 1       14.0       19.0        198  新豐  2012-01-01 13:34:56.790
# 2       15.0       16.0        248  新豐  2012-01-01 13:35:23.217
# 3       16.0        8.0         50  新豐  2012-01-01 13:36:58.827
# 4       14.0       19.0        197  新豐  2012-01-01 13:37:36.580

# %%
# skip
stlend = pd.read_csv(root_path+"3_寄倉入庫檔/stlend.csv")
stlend.head()
# Out:
#              寄倉單單號  供應商代號     商品編號  入庫數量  實際入庫數量                指定到貨日  \
# 0  SL1101010000001   4682  1270447     6       6  2011-01-10 00:00:00
# 1  SL1101010000002   4682  1270407     6       6  2011-01-10 00:00:00
# 2  SL1101010000003   4682  4832324    10       1  2011-01-10 00:00:00
# 3  SL1101010000004   4682  1270451     6       6  2011-01-10 00:00:00
# 4  SL1101010000005   4682  5027747     6       6  2011-01-10 00:00:00
#
#                  實際到貨日  倉別
# 0  2011-01-06 00:00:00  新豐
# 1  2011-01-06 00:00:00  新豐
# 2  2012-03-10 00:00:00  新豐
# 3  2011-01-06 00:00:00  新豐
# 4  2011-01-07 00:00:00  新豐

# %%
# used
cancel_order = pd.read_csv(root_path+"4_訂單取消/cancel_order.csv")
cancel_order.head()
# Out:
#        RG單號                 取消日期  proc_status     取消原因
# 0  18878722  2011-03-03 10:14:00           71  取消-一般-罰
# 1  18464329  2011-02-22 11:27:00           71  取消-一般-罰
# 2  17786430  2011-02-01 13:44:00           71  取消-一般-罰
# 3  18418237  2011-02-21 15:08:00           71  取消-一般-罰
# 4  18356424  2011-02-15 11:07:00           71  取消-一般-罰

# %%
# skip
sku_20120604 = pd.read_csv(root_path+"201201_05/201201_05/sku_20120604.csv")
sku_20120604.head()
# Out:
#    供應商序號     商品編號     供應商料號(型號)        國際條碼  商品材積(長)  商品材積(寬)  商品材積(高)  商品重量  \
# 0   4186  7756196  e11s675-1020  77561961.0     32.0     25.0      3.0   180
# 1   4186  7756197  e11s106-1110  77561978.0     38.0     28.0      1.0   115
# 2   4186  7756198  e11s106-1820  77561985.0     38.0     28.0      1.0   115
# 3   4186  7756199  e11s106-1520  77561992.0     37.0     27.0      1.0   125
# 4   4186  7756200  e11s106-1210  77562005.0     38.0     28.0      1.0   115
#
#    倉別
# 0  秋雨
# 1  秋雨
# 2  秋雨
# 3  秋雨
# 4  秋雨

# %%
order_20120604_volumn = pd.read_csv(root_path+"201201_05/201201_05/order_20120604(volumn).csv", error_bad_lines=False)
order_20120604_volumn.shape
# Out:
# /var/folders/1t/798ky1kx003ft5w1l83k6v9h0000gn/T/ipykernel_85839/1573524181.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   order_20120604_volumn = pd.read_csv(root_path+"201201_05/201201_05/order_20120604(volumn).csv", error_bad_lines=False)
# Skipping line 1762: expected 18 fields, saw 19
# Skipping line 1763: expected 18 fields, saw 19
# Skipping line 1764: expected 18 fields, saw 19
# Skipping line 1765: expected 18 fields, saw 19
# Skipping line 6012: expected 18 fields, saw 19
# Skipping line 13867: expected 18 fields, saw 19
# Skipping line 13868: expected 18 fields, saw 19
# Skipping line 13869: expected 18 fields, saw 19
# Skipping line 29942: expected 18 fields, saw 19
#
# Skipping line 40659: expected 18 fields, saw 19
# Skipping line 40660: expected 18 fields, saw 19
# Skipping line 40661: expected 18 fields, saw 19
# Skipping line 40662: expected 18 fields, saw 19
#
# ...

# %%
order_2011Q1 = pd.read_csv(root_path+"order_2011Q1.csv")
order_2011Q1.head()
# Out:
# /var/folders/1t/798ky1kx003ft5w1l83k6v9h0000gn/T/ipykernel_85839/2376490006.py:1: DtypeWarning: Columns (1,2,3) have mixed types. Specify dtype option on import or set low_memory=False.
#   order_2011Q1 = pd.read_csv(root_path+"order_2011Q1.csv")
#                        客戶代號        RG 商品材積長 商品材積寬  商品材積高  商品材積重量  包裝箱號  \
# 0  ...DNkcBLQA.QJf2TTkvphyy  16808260   NaN   NaN    NaN     NaN   NaN
# 1  ...DNkcBLQA.QJf2TTkvphyy  16808260   NaN   NaN    NaN     NaN   NaN
# 2  ...DNkcBLQA.QJf2TTkvphyy  16808260   NaN   NaN    NaN     NaN   NaN
# 3  ...DNkcBLQA.QJf2TTkvphyy  17566467   NaN   NaN    NaN     NaN   NaN
# 4  .._e3FYi8wUzSNtMDc7nujk-  18680300   NaN   NaN    NaN     NaN   NaN
#
#               訂單編號             子單編號        出貨單號                   訂單成立時間  \
# 0  RM1101060042603  RS1101060060321  8315097696  2011-01-06 23:29:00.000
# 1  RM1101060042603  RS1101060060322  8315098302  2011-01-06 23:29:00.000
# 2  RM1101060042603  RS1101060060323  8315098302  2011-01-06 23:29:00.000
# ...

# %%
order_2011Q2 = pd.read_csv(root_path+"order_2011Q2.csv")
order_2011Q2.head()
# Out:
# /var/folders/1t/798ky1kx003ft5w1l83k6v9h0000gn/T/ipykernel_85839/2647105582.py:1: DtypeWarning: Columns (1,2,3) have mixed types. Specify dtype option on import or set low_memory=False.
#   order_2011Q2 = pd.read_csv(root_path+"order_2011Q2.csv")
#                        客戶代號        RG 商品材積長 商品材積寬  商品材積高  商品材積重量  包裝箱號  \
# 0      ...aEk2_YX0mzq_jSaU-  21168538   NaN   NaN    NaN     NaN   NaN
# 1      ...IJBx0o3uKe2oBVgM-  21255765   NaN   NaN    NaN     NaN   NaN
# 2      ...IJBx0o3uKe2oBVgM-  21255765   NaN   NaN    NaN     NaN   NaN
# 3  ...uKlv0YgumW5zCqCMMe1Nx  21004020   NaN   NaN    NaN     NaN   NaN
# 4  ...v3kmyOHg.wptmk6ssT.E-  20370423   NaN   NaN    NaN     NaN   NaN
#
#               訂單編號             子單編號         出貨單號                   訂單成立時間  \
# 0  RM1104270010810  RS1104270015844   8370873291  2011-04-27 11:10:00.000
# 1  RM1104290011706  RS1104290016776  94394358062  2011-04-29 11:49:00.000
# 2  RM1104290011706  RS1104290016777  94394358062  2011-04-29 11:49:00.000
# ...

# %%
order_2011Q3 = pd.read_csv(root_path+"order_2011Q3.csv")
order_2011Q3.head()
# Out:
# /var/folders/1t/798ky1kx003ft5w1l83k6v9h0000gn/T/ipykernel_85839/4146744351.py:1: DtypeWarning: Columns (1,2,3,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   order_2011Q3 = pd.read_csv(root_path+"order_2011Q3.csv")
#                        客戶代號        RG 商品材積長 商品材積寬  商品材積高  商品材積重量  包裝箱號  \
# 0  ...3dB1mBni.2ZXee5SLEg--  25596392   NaN   NaN    NaN     NaN   NaN
# 1  ...3dB1mBni.2ZXee5SLEg--  25596392   NaN   NaN    NaN     NaN   NaN
# 2  ...3dB1mBni.2ZXee5SLEg--  25596392   NaN   NaN    NaN     NaN   NaN
# 3      ...aEk2_YX0mzq_jSaU-  24321841   NaN   NaN    NaN     NaN   NaN
# 4  ...BHkEYIAQU8l1v1E4BHKk-  24897848   NaN   NaN    NaN     NaN   NaN
#
#               訂單編號             子單編號            出貨單號                   訂單成立時間  \
# 0  RM1108170028614  RS1108170045937      2569344180  2011-08-17 20:20:00.000
# 1  RM1108170028614  RS1108170045938      2569344180  2011-08-17 20:20:00.000
# ...

# %%
order_2011Q4 = pd.read_csv(root_path+"order_2011Q4.csv")
order_2011Q4.head()
# Out:
# /var/folders/1t/798ky1kx003ft5w1l83k6v9h0000gn/T/ipykernel_85839/1301982178.py:1: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   order_2011Q4 = pd.read_csv(root_path+"order_2011Q4.csv")
#                            客戶代號        RG  商品材積長  商品材積寬  商品材積高  商品材積重量 包裝箱號  \
# 0  ...7um1fNnobIUouRM6M6TF5KCQ-  30700380    NaN    NaN    NaN     NaN  NaN
# 1  ...7um1fNnobIUouRM6M6TF5KCQ-  30700380    NaN    NaN    NaN     NaN  NaN
# 2  ...7um1fNnobIUouRM6M6TF5KCQ-  30700380    NaN    NaN    NaN     NaN  NaN
# 3  ...7um1fNnobIUouRM6M6TF5KCQ-  30700380    NaN    NaN    NaN     NaN  NaN
# 4  ...7um1fNnobIUouRM6M6TF5KCQ-  30700380    NaN    NaN    NaN     NaN  NaN
#
#               訂單編號             子單編號        出貨單號                   訂單成立時間  \
# 0  RM1112140036303  RS1112140053556  3151433350  2011-12-14 22:24:00.000
# 1  RM1112140036304  RS1112140053557  3028209725  2011-12-14 22:25:00.000
# ...

# %%
order_2012Q1 = pd.read_csv(root_path+"order_2012Q1.csv")
order_2012Q1.head()
# Out:
#                        客戶代號        RG  商品材積長  商品材積寬  商品材積高   商品材積重量  \
# 0  ...DNkcBLQA.QJf2TTkvphyy  31514220   39.0   41.0   64.0   8580.0
# 1  ...uKlv0YgumW5zCqCMMe1Nx  33877180    NaN    NaN    NaN      NaN
# 2  .._4AsF8owDRpb7dinkIqLM-  34607782    NaN    NaN    NaN      NaN
# 3  .._4AsF8owDRpb7dinkIqLM-  34616393    NaN    NaN    NaN      NaN
# 4  .._AWj8Js3huGak6h1hcEwvn  32580683   28.0   31.0   37.0  19095.0
#
#           包裝箱號             訂單編號             子單編號            出貨單號  \
# 0  b0000000000  RM1201020001908  RS1201020002603      8332778025
# 1          NaN  RM1202240029493  RS1202240042690    177109409304
# 2          NaN  RM1203100016202  RS1203100024265  06988422027818
# 3          NaN  RM1203100022140  RS1203100032711      3031080760
# 4  b0000000000  RM1201270021177  RS1201270031304      8332929600
#
#                     訂單成立時間     商品編號                最晚出貨日                  出貨日  \
# 0  2012-01-02 00:54:00.000  4136301  2012-01-04 00:54:00  2012-01-02 15:42:00
# ...

# %%
order_2012Q2 = pd.read_csv(root_path+"order_2012Q2.csv")
order_2012Q2.head()

# %%
retgood_20120823 = pd.read_csv(root_path+"retgood_20120823/retgood_20120823.csv")
retgood_20120823.head()
# Out:
#    RG單號             RM單號             RS單號           退貨單號  \
# 0     0  RM0908040019735  RS0908040030669  201106092851R
# 1     0  RM0911260016752  RS0911260025793  201102011930R
# 2     0  RM1001290007881  RS1001290011509  201101030603R
# 3     0  RM1002200003288  RS1002200004471  201105032478R
# 4     0  RM1003100012235  RS1003100018134  201106081582R
#
#                    退貨單成立日期                   退貨完成日期     退貨原因
# 0  2011-06-09 16:38:14.050  2011-06-14 17:11:28.000  商品瑕疵/故障
# 1  2011-02-01 15:43:49.687  2011-02-10 17:09:46.000  商品瑕疵/故障
# 2  2011-01-03 09:40:43.207  2011-01-03 10:24:40.000  商品瑕疵/故障
# 3  2011-05-03 18:11:52.007  2011-05-03 18:10:12.000  商品瑕疵/故障
# 4  2011-06-08 12:41:23.997  2011-06-09 11:23:35.000  商品瑕疵/故障

# %%
WMS_EIQ_20110331 = pd.read_csv(root_path+"WMS_EIQ/20110331.csv")
WMS_EIQ_20110331.head()
# Out:
#                        客戶代號        RG  商品材積長  商品材積寬  商品材積高  商品材積重量  包裝箱號  \
# 0  ..XRXfHnnnnPeab8x3vYxyDD  20165469    NaN    NaN    NaN     NaN   NaN
# 1  ..XRXfHnnnnPeab8x3vYxyDD  20165469    NaN    NaN    NaN     NaN   NaN
# 2  ..XRXfHnnnnPeab8x3vYxyDD  20165469    NaN    NaN    NaN     NaN   NaN
# 3  ..XRXfHnnnnPeab8x3vYxyDD  20165469    NaN    NaN    NaN     NaN   NaN
# 4  ..XRXfHnnnnPeab8x3vYxyDD  20165469    NaN    NaN    NaN     NaN   NaN
#
#               訂單編號             子單編號           出貨單號                   訂單成立時間  \
# 0  RM1103310029273  RS1103310043070   977111495706  2011-03-31 21:16:00.000
# 1  RM1103310029274  RS1103310043071  便利帶1000313086  2011-03-31 21:16:00.000
# 2  RM1103310029275  RS1103310043072  便利帶1000320128  2011-03-31 21:16:00.000
# 3  RM1103310029276  RS1103310043073  便利帶1000328894  2011-03-31 21:16:00.000
# 4  RM1103310029277  RS1103310043074  便利帶1000313850  2011-03-31 21:16:00.000
#
#       商品編號                最晚出貨日                  出貨日  郵遞區號  \
# ...

# %%
supli_ship_conve = pd.read_csv(root_path+"供應商出貨_直店配/供應商出貨_直店配.csv")
supli_ship_conve.head()
# Out:
# /var/folders/1t/798ky1kx003ft5w1l83k6v9h0000gn/T/ipykernel_85839/3668884346.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   supli_ship_direct = pd.read_csv(root_path+"供應商出貨_直店配/供應商出貨_直店配.csv")
#        RG單號             RM單號      出貨單號               退貨完成日期 失敗代碼       失敗原因  \
# 0  16659155  RM1101030035619  20000591  2011-01-16 07:21:00   01  門市刷退-正常一退
# 1  16669149  RM1101040001617  20000603  2011-01-18 07:21:00   01  門市刷退-正常一退
# 2  16673919  RM1101040006251  20000599  2011-01-16 07:21:00   01  門市刷退-正常一退
# 3  16675832  RM1101040008138  20000596  2011-01-19 07:21:00   01  門市刷退-正常一退
# 4  16687310  RM1101040018810  20000641  2011-01-19 07:21:00   01  門市刷退-正常一退
#
#            超商通路
# 0  直配統一超商(7-11)
# 1  直配統一超商(7-11)
# 2  直配統一超商(7-11)
# 3  直配統一超商(7-11)
# 4  直配統一超商(7-11)

# %%
warehouse_ship_conve = pd.read_csv(root_path+"倉出_店配/倉出_店配.csv")
warehouse_ship_conve.head()
# Out:
#        RG單號             RM單號  出貨單號                   退貨完成日期     退貨原因 超商通路
# 0  16559032  RM1101010008525   NaN  2011-01-02 22:01:14.667  門市閉店(4)   待查
# 1  16574773  RM1101010023649   NaN  2011-01-02 22:22:12.357  門市閉店(4)   待查
# 2  16648226  RM1101030025849   NaN  2011-01-03 22:20:55.123  門市閉店(4)   待查
# 3  16648448  RM1101030026080   NaN  2011-01-03 22:20:55.967  門市閉店(4)   待查
# 4  16671652  RM1101040003980   NaN  2011-01-04 22:01:02.873  門市閉店(4)   待查
